# %% [markdown]
# # 1. Introduction

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('Test figure') 
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(3,3))
ax.bar(x=['A','B','C'], height=[3.1,7,4.2], color='r')
ax.set_xlabel(xlabel='X title', size=20)
ax.set_ylabel(ylabel='Y title' , color='b', size=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
ax.plot(['Alice','Bob','Catherine'], [4,6,3], color='r')
ax.set_xlabel('TITLE 1')
for tick in ax.get_xticklabels():
 tick.set_rotation(45)
plt.show()

# %% [markdown]
# In the codes above, we created an axes object, created a line plot on top
# of it, added a title, and rotated all the x-tick labels by 45 degrees
# counterclockwise.

# %%
# 2D kde plots
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(1)
numerical_1 = np.random.randn(100)
np.random.seed(2)
numerical_2 = np.random.randn(100)
fig, ax = plt.subplots(figsize=(3,3))
sns.kdeplot(data=numerical_1,
 data2= numerical_2,
 ax=ax,
 shade=True, 
 color="blue", 
 bw=1)
plt.show()
# Out:
# C:\Users\asfar\AppData\Local\Temp\ipykernel_16372\4078139856.py:10: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(data=numerical_1,
# C:\Users\asfar\AppData\Local\Temp\ipykernel_16372\4078139856.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=numerical_1,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 10
#       8 numerical_2 = np.random.randn(100)
#       9 fig, ax = plt.subplots(figsize=(3,3))
# ---> 10 sns.kdeplot(data=numerical_1,
#      11  data2= numerical_2,
#      12  ax=ax,
#      13  shade=True,
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

numerical_1 = np.random.randn(100)
numerical_2 = np.random.randn(100)

fig, ax = plt.subplots(figsize=(3, 3))

# Plot KDE for numerical_1
sns.kdeplot(data=numerical_1, ax=ax, shade=True, color="blue", bw_method=1)

# Plot KDE for numerical_2
sns.kdeplot(data=numerical_2, ax=ax, shade=True, color="red", bw_method=1)

plt.show()
# Out:
# C:\Users\asfar\AppData\Local\Temp\ipykernel_16372\1799462429.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=numerical_1, ax=ax, shade=True, color="blue", bw_method=1)
# C:\Users\asfar\AppData\Local\Temp\ipykernel_16372\1799462429.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=numerical_2, ax=ax, shade=True, color="red", bw_method=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

numerical_1 = np.random.randn(100)
numerical_2 = np.random.randn(100)

fig, ax = plt.subplots(figsize=(3, 3))

# Plot KDE for numerical_1
sns.kdeplot(data=numerical_1, ax=ax, fill=True, color="blue", bw_method=1)

# Plot KDE for numerical_2
sns.kdeplot(data=numerical_2, ax=ax, fill=True, color="red", bw_method=1)

plt.show()

# %%
# heat map
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame(dict(categorical_1=['apple', 'banana', 
'grapes',
 'apple', 'banana', 
'grapes',
                                      'apple', 'banana', 
'grapes'], 
 categorical_2=
['A','A','A','B','B','B','C','C','C'], 
 value=[10,2,5,7,3,15,1,6,8]))
pivot_table = df.pivot("categorical_1", "categorical_2", 
"value")
# try printing out pivot_table to see what it looks like!
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(data=pivot_table, 
 cmap=sns.color_palette("Blues"),
 ax=ax)
plt.show()
# Out:
# C:\Users\asfar\AppData\Local\Temp\ipykernel_16372\2577670308.py:15: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_table = df.pivot("categorical_1", "categorical_2",

# %%
# heat map
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame(dict(categorical_1=['apple', 'banana', 
'grapes',
 'apple', 'banana', 
'grapes',
                                      'apple', 'banana', 
'grapes'], 
 categorical_2=
['A','A','A','B','B','B','C','C','C'], 
 value=[10,2,5,7,3,15,1,6,8]))
pivot_table = df.pivot(index="categorical_1", columns="categorical_2", 
values="value")
# try printing out pivot_table to see what it looks like!
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(data=pivot_table, 
 cmap=sns.color_palette("Blues"),
 ax=ax)
plt.show()

# %% [markdown]
# # 2. Overlay Plots

# %%
fig, ax = plt.subplots(figsize=(4,4))
sns.lineplot(x=['A','B','C','D'], 
 y=[4,2,5,3],
 color='r',
 ax=ax)
sns.lineplot(x=['A','B','C','D'], 
 y=[1,6,2,4], 
 color='b',
 ax=ax) 
ax.legend(['alpha', 'beta'], facecolor='w')
plt.show()

# %% [markdown]
# Or, we can combine a bar chart and a line chart with the same x-axis
# but different y-axis:

# %%
sns.set(style="white", rc={"lines.linewidth": 3})
fig, ax1 = plt.subplots(figsize=(4,4))
ax2 = ax1.twinx()
sns.barplot(x=['A','B','C','D'],
 y=[100,200,135,98], 
 color='#004488',
 ax=ax1)
sns.lineplot(x=['A','B','C','D'], 
 y=[4,2,5,3],
 color='r',
 marker="o",
 ax=ax2)
plt.show()
sns.set()

# %% [markdown]
# Combining different barplots into one grouped barplot also adds one
# categorical dimension to the plot (one more categorical variable).

# %%
import matplotlib.pyplot as plt
categorical_1 = ['A', 'B', 'C', 'D']
colors = ['green', 'red', 'blue', 'orange']
numerical = [[6, 9, 2, 7],
 [6, 7, 3, 8],
 [9, 11, 13, 15],
 [3, 5, 9, 6]]
number_groups = len(categorical_1) 
bin_width = 1.0/(number_groups+1)
fig, ax = plt.subplots(figsize=(6,6))
for i in range(number_groups):
 ax.bar(x=np.arange(len(categorical_1)) + i*bin_width, 
 height=numerical[i],
 width=bin_width,
 color=colors[i],
 align='center')
ax.set_xticks(np.arange(len(categorical_1)) + 
number_groups/(2*(number_groups+1)))
# number_groups/(2*(number_groups+1)): offset of xticklabel
ax.set_xticklabels(categorical_1)
ax.legend(categorical_1, facecolor='w')
plt.show()

# %% [markdown]
# In the code example above, you can customize variable names, colors,
# and figure size. number_groups and bin_width are calculated based on
# the input data. I then wrote a for-loop to plot the bars, one color at a
# time, and set the ticks and legends in the very end.

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", 
 hue="size", size="size",
 sizes=(20, 200), hue_norm=(0, 7),
 legend="full", data=tips)
plt.show()

# %% [markdown]
# # 3. Partition the Figure Using GridSpec

# %%
fig = plt.figure(figsize=(7,7))
gs = gridspec.GridSpec(nrows=3, 
 ncols=3, 
 figure=fig, 
 width_ratios= [1, 1, 1],
 height_ratios=[1, 1, 1],
 wspace=0.3,
 hspace=0.3)
ax1 = fig.add_subplot(gs[0, 0])
ax1.text(0.5, 0.5, 'ax1: gs[0, 0]', fontsize=12, 
fontweight="bold", va="center", ha="center") # adding text to ax1
ax2 = fig.add_subplot(gs[0, 1:3])
ax2.text(0.5, 0.5, 'ax2: gs[0, 1:3]', fontsize=12, 
fontweight="bold", va="center", ha="center")
ax3 = fig.add_subplot(gs[1:3, 0:2])
ax3.text(0.5, 0.5, 'ax3: gs[1:3, 0:2]', fontsize=12, 
fontweight="bold", va="center", ha="center")
ax4 = fig.add_subplot(gs[1:3, 2])
ax4.text(0.5, 0.5, 'ax4: gs[1:3, 2]', fontsize=12, 
fontweight="bold", va="center", ha="center")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 fig = plt.figure(figsize=(7,7))
# ----> 2 gs = gridspec.GridSpec(nrows=3,
#       3  ncols=3,
#       4  figure=fig,
#       5  width_ratios= [1, 1, 1],
#       6  height_ratios=[1, 1, 1],
#       7  wspace=0.3,
#       8  hspace=0.3)
#       9 ax1 = fig.add_subplot(gs[0, 0])
#      10 ax1.text(0.5, 0.5, 'ax1: gs[0, 0]', fontsize=12,
#      11 fontweight="bold", va="center", ha="center") # adding text to ax1
#
# NameError: name 'gridspec' is not defined

# %%
from matplotlib import gridspec

fig = plt.figure(figsize=(7,7))
gs = gridspec.GridSpec(nrows=3, 
 ncols=3, 
 figure=fig, 
 width_ratios= [1, 1, 1],
 height_ratios=[1, 1, 1],
 wspace=0.3,
 hspace=0.3)
ax1 = fig.add_subplot(gs[0, 0])
ax1.text(0.5, 0.5, 'ax1: gs[0, 0]', fontsize=12, 
fontweight="bold", va="center", ha="center") # adding text to ax1
ax2 = fig.add_subplot(gs[0, 1:3])
ax2.text(0.5, 0.5, 'ax2: gs[0, 1:3]', fontsize=12, 
fontweight="bold", va="center", ha="center")
ax3 = fig.add_subplot(gs[1:3, 0:2])
ax3.text(0.5, 0.5, 'ax3: gs[1:3, 0:2]', fontsize=12, 
fontweight="bold", va="center", ha="center")
ax4 = fig.add_subplot(gs[1:3, 2])
ax4.text(0.5, 0.5, 'ax4: gs[1:3, 2]', fontsize=12, 
fontweight="bold", va="center", ha="center")
plt.show()

# %% [markdown]
# In the example, we first partition the figure into 3*3 = 9 small boxes
# with gridspec.GridSpec(), and then define a few axes objects. Each
# axes object could contain one or more boxes. Say in the codes above,
# gs[0, 1:3] = gs[0, 1] + gs[0, 2] is assigned to axes object ax2. wspace
# and hspace are parameters controlling the space between plots.
