# %% [markdown]
# # 1. Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 2. Relational Plots

# %% [markdown]
# Statistical analysis is a process of understanding how variables in a dataset related to each other and how those relationships depend on other variables. Visualization can be a core component of this process because when data are visualized properly, the human system can see trends and patterns that indicate a relationship.

# %% [markdown]
# 3 categories of **relational plots**:
# 1. replot
# 2. scatterplot
# 3. lineplot

# %% [markdown]
# ## 2.1 Replot

# %% [markdown]
# This is a figure-level function for visualizing statistical relationships using two common approaches:
# 1. scatter plots
# 2. line plots

# %% [markdown]
# `replot()` combines a `FaceGrid` with one of two axes-level functions:
# a. Scatterplot with kind='scatter'
# b. Lineplot with kind='line'

# %%
sns.relplot(
    x=None, y=None, hue=None, size=None, style=None, data=None, \
    row=None, col=None, palette=None, markers=None, kind='scatter'
)
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# While the points are plotted in two dimensions, another dimension can be added to the plot by colouring the points according to a third variable. In seaborn, this is referred to as being a **hue semantic**.

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# To emphasize the difference between the classes, and to improve accessibility, you can use a different marker style for each class:

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='smoker', \
           data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# It is also possible to represent 4 variables by changing the hue and style of each point independently.

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='time', \
           data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# If the hue semantic is numeric, the default colouring switches to a sequential palette:

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The 3rd kind of semantic variable changes the size of each point:

# %%
sns.relplot(x='total_bill', y='tip', size='size', data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', col='smoker', hue='time', \
           data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', col='smoker', row='sex', \
            hue='time', data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', kind='line', \
          data=tips);
# Out:
# D:\Program Files\anaconda\envs\itil\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 2.2 Scatterplot

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Assigning a variable to `hue` will map its level to the colour of the points:

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
iris = sns.load_dataset('iris')
iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
sns.scatterplot(x=iris.sepal_length,
               y=iris.sepal_width,
               hue=iris.species)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# Assigning the same variable to `style` will also vary the markers and create a more accessible plot:

# %%
sns.scatterplot(
    data=tips,
    x='total_bill',
    y='tip',
    hue='time',
    style='time'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(
    x=iris.sepal_length,
    y=iris.sepal_width,
    hue=iris.species,
    style=iris.species,
)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# If the variable assigned to `hue` is numeric, the semantic mapping will be quantitative and use a different default palette:

# %%
sns.scatterplot(data=tips,
               x='total_bill',
               y='tip',
               hue='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Pass the name of a categorical paletter or explicit colours to force categorical mapping of the `hue` variable:

# %%
sns.scatterplot(data=tips,
               x='total_bill',
               y='tip',
               hue='size',
               palette='deep')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
