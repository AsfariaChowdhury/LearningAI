# %% [markdown]
# # 1. Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(10)
y = np.random.rand(10)

figure1 = plt.plot(x,y)

# %%
ax = plt.subplot()
ax.plot(x,y)

# %%
fig1, ((ax1,ax2),(ax3,ax4)) \
    = plt.subplots(2,2)

# %%
x1 = np.random.rand(10)
x2 = np.random.rand(10)
x3 = np.random.rand(10)
x4 = np.random.rand(10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)
y3 = np.random.rand(10)
y4 = np.random.rand(10)

figure2, ((ax1,ax2), (ax3,ax4)) \
    = plt.subplots(2,2)
ax1.plot(x1,y1)
ax2.plot(x2,y2)
ax3.plot(x3,y3)
ax4.plot(x4,y4)

plt.show()

# %% [markdown]
# # 2. Another Method of Adding Multiple Plots

# %%
fig = plt.figure()
new_plot = fig.add_subplot(111)
new_plot.plot(x,y)

# %% [markdown]
# # 3. Difference between “axes” and “axis” in matplotlib?

# %% [markdown]
# In the context of matplotlib, axes is not the plural form of axis, it actually denotes the plotting area, including all axis.

# %% [markdown]
# ![image.png](attachment:338b9597-e5ba-4182-9c3d-786e837df3c4.png)

# %% [markdown]
# **Axes:** This is what you think of as a plot, it is the region of the image with the data space (marked as the inner blue box). A given figure can contain many Axes, but a given Axes object can only be in one Figure. The Axes contains two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) which take care of the data limits (the data limits can also be controlled via set via the set_xlim() and set_ylim() Axes methods). Each Axes has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).

# %% [markdown]
# **Axis:** These are the number-line-like objects (circled in green). They take care of setting the graph limits and generating the ticks (the marks on the axis) and ticklabels (strings labeling the ticks). The location of the ticks is determined by a Locator object and the ticklabel strings are formatted by a Formatter. The combination of the correct Locator and Formatter gives very fine control over the tick locations and labels.
